# %%
from datetime import datetime

# %%
from ib_insync import *
from Class_IBKR_IB import *
ibkr = IBKR_IB()

ibkr.ib.disconnect()

# %%
clientId = int(datetime.now().strftime("%H%M%S"))
await ibkr.ib.connectAsync('127.0.0.1', 7496, clientId=clientId)

print("Connected:", ibkr.ib.isConnected())
# Out:
# Connected: True

# %%
contract = Stock('IBIT', 'SMART', 'USD')
[contract] = await ibkr.ib.qualifyContractsAsync(contract)

dict_ = vars(contract)

for k, v in dict_.items():
    print(type(v), k, v)
# Out:
# <class 'str'> secType STK
# <class 'int'> conId 677037673
# <class 'str'> symbol IBIT
# <class 'str'> lastTradeDateOrContractMonth
# <class 'float'> strike 0.0
# <class 'str'> right
# <class 'str'> multiplier
# <class 'str'> exchange SMART
# <class 'str'> primaryExchange NASDAQ
# <class 'str'> currency USD
# <class 'str'> localSymbol IBIT
# <class 'str'> tradingClass NMS
# <class 'bool'> includeExpired False
# <class 'str'> secIdType
# <class 'str'> secId
# <class 'str'> description
# <class 'str'> issuerId
# <class 'str'> comboLegsDescrip
# <class 'list'> comboLegs []
# <class 'NoneType'> deltaNeutralContract None

# %%
details_list = await ibkr.ib.reqContractDetailsAsync(contract)

for details in details_list:
    dict_ = vars(details)

    for k, v in dict_.items():
        print(type(v), k, v)
# Out:
# <class 'ib_insync.contract.Contract'> contract Contract(secType='STK', conId=677037673, symbol='IBIT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='IBIT', tradingClass='NMS')
# <class 'str'> marketName NMS
# <class 'float'> minTick 0.01
# <class 'str'> orderTypes ACTIVETIM,AD,ADDONT,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DARKONLY,DARKPOLL,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,DUR,GAT,GTC,GTD,GTT,HID,IBKRATS,ICE,IMB,IOC,LIT,LMT,LOC,MIDPX,MIT,MKT,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,OPGREROUT,PEGBENCH,PEGMID,POSTATS,POSTONLY,PREOPGRTH,PRICECHK,REL,REL2MID,RELPCTOFS,RPI,RTH,SCALE,SCALEODD,SCALERST,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,SWEEP,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF
# <class 'str'> validExchanges SMART,AMEX,NYSE,CBOE,PHLX,ISE,CHX,ARCA,ISLAND,DRCTEDGE,BEX,BATS,EDGEA,BYX,IEX,EDGX,FOXRIVER,PEARL,NYSENAT,LTSE,MEMX,IBEOS,OVERNIGHT,TPLUS0,PSX,T24X
# <class 'int'> priceMagnifier 1
# <class 'int'> underConId 0
# ...

# %%
ticker = ibkr.ib.reqMktData(contract, '', False, False)

await asyncio.sleep(2)   # allow data to arrive

dict_ = vars(ticker)

for k, v in dict_.items():
    print(type(v), k, v)
# Out:
# <class 'ib_insync.contract.Stock'> contract Stock(conId=677037673, symbol='IBIT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='IBIT', tradingClass='NMS')
# <class 'datetime.datetime'> time 2026-04-28 02:02:24.586499+00:00
# <class 'int'> marketDataType 1
# <class 'float'> minTick 0.01
# <class 'float'> bid 43.66
# <class 'float'> bidSize 168.0
# <class 'str'> bidExchange
# <class 'float'> ask 43.7
# <class 'float'> askSize 401.0
# <class 'str'> askExchange
# <class 'float'> last 43.67
# <class 'float'> lastSize 1.0
# <class 'str'> lastExchange
# <class 'float'> prevBid nan
# <class 'float'> prevBidSize nan
# <class 'float'> prevAsk nan
# <class 'float'> prevAskSize nan
# <class 'float'> prevLast nan
# <class 'float'> prevLastSize nan
# <class 'float'> volume 859.0
# <class 'float'> open 44.02
# <class 'float'> high 44.37
# <class 'float'> low 43.325
# <class 'float'> close 43.560001
# <class 'float'> vwap nan
# <class 'float'> low13week nan
# ...

# %%
contract = Future(symbol='BRR', lastTradeDateOrContractMonth='202606', exchange='CME', currency='USD')
[contract] = await ibkr.ib.qualifyContractsAsync(contract)

dict_ = vars(contract)

for k, v in dict_.items():
    print(type(v), k, v)
# Out:
# <class 'str'> secType FUT
# <class 'int'> conId 751356962
# <class 'str'> symbol BRR
# <class 'str'> lastTradeDateOrContractMonth 20260626
# <class 'float'> strike 0.0
# <class 'str'> right
# <class 'str'> multiplier 5
# <class 'str'> exchange CME
# <class 'str'> primaryExchange
# <class 'str'> currency USD
# <class 'str'> localSymbol BTCM6
# <class 'str'> tradingClass BTC
# <class 'bool'> includeExpired False
# <class 'str'> secIdType
# <class 'str'> secId
# <class 'str'> description
# <class 'str'> issuerId
# <class 'str'> comboLegsDescrip
# <class 'list'> comboLegs []
# <class 'NoneType'> deltaNeutralContract None

# %%
ticker = ibkr.ib.reqMktData(contract, '', False, False)

await asyncio.sleep(2)   # allow data to arrive

dict_ = vars(ticker)

for k, v in dict_.items():
    print(type(v), k, v)
# Out:
# <class 'ib_insync.contract.Future'> contract Future(conId=751356962, symbol='BRR', lastTradeDateOrContractMonth='20260626', multiplier='5', exchange='CME', currency='USD', localSymbol='BTCM6', tradingClass='BTC')
# <class 'datetime.datetime'> time 2026-04-28 02:02:28.655838+00:00
# <class 'int'> marketDataType 1
# <class 'float'> minTick 5.0
# <class 'float'> bid 77680.0
# <class 'float'> bidSize 1.0
# <class 'str'> bidExchange
# <class 'float'> ask 77750.0
# <class 'float'> askSize 1.0
# <class 'str'> askExchange
# <class 'float'> last 77790.0
# <class 'float'> lastSize 1.0
# <class 'str'> lastExchange
# <class 'float'> prevBid 77690.0
# <class 'float'> prevBidSize nan
# <class 'float'> prevAsk 77755.0
# <class 'float'> prevAskSize 2.0
# <class 'float'> prevLast nan
# <class 'float'> prevLastSize nan
# <class 'float'> volume 13.0
# <class 'float'> open 77440.0
# <class 'float'> high 77985.0
# <class 'float'> low 77440.0
# <class 'float'> close 77510.0
# <class 'float'> vwap nan
# ...

# %%
contract = await ibkr.contract_by_conId(541686651)

[contract] = await ibkr.ib.qualifyContractsAsync(contract)

dict_ = vars(contract)

for k, v in dict_.items():
    print(type(v), k, v)
# Out:
# <class 'str'> secType CRYPTO
# <class 'int'> conId 541686651
# <class 'str'> symbol BTC
# <class 'str'> lastTradeDateOrContractMonth
# <class 'float'> strike 0.0
# <class 'str'> right
# <class 'str'> multiplier
# <class 'str'> exchange ZEROHASH
# <class 'str'> primaryExchange
# <class 'str'> currency USD
# <class 'str'> localSymbol BTC.USD
# <class 'str'> tradingClass BTC
# <class 'bool'> includeExpired False
# <class 'str'> secIdType
# <class 'str'> secId
# <class 'str'> description
# <class 'str'> issuerId
# <class 'str'> comboLegsDescrip
# <class 'list'> comboLegs []
# <class 'NoneType'> deltaNeutralContract None

# %%
details_list = await ibkr.ib.reqContractDetailsAsync(contract)

for details in details_list:
    dict_ = vars(details)

    for k, v in dict_.items():
        print(type(v), k, v)
# Out:
# <class 'ib_insync.contract.Contract'> contract Contract(secType='CRYPTO', conId=541686651, symbol='BTC', exchange='ZEROHASH', currency='USD', localSymbol='BTC.USD', tradingClass='BTC')
# <class 'str'> marketName BTC
# <class 'float'> minTick 0.25
# <class 'str'> orderTypes AD,ADJUST,ALERT,BASKET,BENCHPX,CASHQTY,COND,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,IOC,LMT,MKT,NMIN,NONALGO,WHATIF
# <class 'str'> validExchanges ZEROHASH
# <class 'int'> priceMagnifier 1
# <class 'int'> underConId 0
# <class 'str'> longName Bitcoin cryptocurrency
# <class 'str'> contractMonth
# <class 'str'> industry
# <class 'str'> category
# <class 'str'> subcategory
# <class 'str'> timeZoneId US/Eastern
# <class 'str'> tradingHours 20260524:0300-20260525:1600;20260525:1601-20260526:1600;20260526:1601-20260527:1600;20260527:1601-20260528:1600;20260528:1601-20260529:1600
# ...
