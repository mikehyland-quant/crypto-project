# %%
file_suffix = 'Bybit'
module_name = file_suffix + 'Feed' # or 'SpotFeed'

# %%
# --- system setup ---
import importlib
import sys
import os
sys.path.append(os.path.abspath(".."))
print(sys.path)
# Out:
# ['C:\\Users\\micha\\anaconda3\\python313.zip', 'C:\\Users\\micha\\anaconda3\\DLLs', 'C:\\Users\\micha\\anaconda3\\Lib', 'C:\\Users\\micha\\anaconda3', '', 'C:\\Users\\micha\\anaconda3\\Lib\\site-packages', 'C:\\Users\\micha\\anaconda3\\Lib\\site-packages\\twsq-1.0.0-py3.13.egg', 'C:\\Users\\micha\\anaconda3\\Lib\\site-packages\\win32', 'C:\\Users\\micha\\anaconda3\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\micha\\anaconda3\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\micha\\OneDrive\\My Python Code\\Crypto Project']

# %%
# --- feeds ---
#from ws_feeds import WSFeedManager
import_name = f"ws_feeds.Class_WS_{file_suffix}"
module = importlib.import_module(import_name)
print(import_name, module_name)
# Out:
# ws_feeds.Class_WS_Bybit BybitFeed

# %%
feed_cls = getattr(module, module_name)
print(feed_cls)
# Out:
# <class 'ws_feeds.Class_WS_Bybit.BybitFeed'>

# %%
df, _ = feed_cls.get_product_info()
# df, _ = await module.KrakenSpotFeed._get_product_info_ws()

# %%
print(df)
df.to_csv(file_suffix + ".csv")
# Out:
# Empty DataFrame
# Columns: []
# Index: []
